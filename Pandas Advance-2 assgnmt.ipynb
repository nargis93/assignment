# %%
import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
df[0:2]
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3

# %%
Q 2 ANS =
The loc() function is label based data selecting method which means that we have to pass the name of the row or column which
we want to select. This method includes the last element of the range passed in it, unlike iloc().
loc() can accept the boolean data unlike iloc(). Many operations can be performed using the loc() method
The iloc() function is an indexed-based selecting method which means that we have to pass an integer index in the method to
select a specific row/column. This method does not include the last element of
the range passed in it unlike loc(). iloc() does not accept the boolean data unlike loc(). Operations performed using iloc()

# %%
Q3 ANS =
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1.loc[1]
column_1    0.340867
column_2    0.829477
column_3    0.325304
column_4    0.265154
column_5    0.260182
column_6    0.794456
Name: 1, dtype: float64
df1.iloc[1]
column_1    0.944687
column_2    0.061916
column_3    0.842143
column_4    0.036029
column_5    0.338569
column_6    0.336963
Name: 2, dtype: float64
new_df =df1.reindex([3,0,4,1,5,2,6])
new_df
column_1	column_2	column_3	column_4	column_5	column_6
3	0.228340	0.634720	0.962651	0.773891	0.122647	0.128764
0	NaN	NaN	NaN	NaN	NaN	NaN
4	0.810398	0.538974	0.944772	0.017774	0.360737	0.926335
1	0.340867	0.829477	0.325304	0.265154	0.260182	0.794456
5	0.252251	0.403358	0.314613	0.372372	0.184625	0.287014
2	0.944687	0.061916	0.842143	0.036029	0.338569	0.336963
6	0.496686	0.516271	0.212259	0.397534	0.282830	0.141192
new_df.loc[3]
column_1    0.228340
column_2    0.634720
column_3    0.962651
column_4    0.773891
column_5    0.122647
column_6    0.128764
Name: 3, dtype: float64
new_df.iloc[3]
column_1    0.340867
column_2    0.829477
column_3    0.325304
column_4    0.265154
column_5    0.260182
column_6    0.794456
Name: 1, dtype: float64
 
from this output we can conclude that in loc function it shows row ,while iloc gives output as per indices as shown in 
above example.

Q 4 ANS =
new_df.mean()
column_1    0.437054
column_2    0.478561
column_3    0.366765
column_4    0.413047
column_5    0.529311
column_6    0.388742
dtype: float64

new_df['column_2'].std()

0.29240990111177717

Q 5 ANS =
df1.loc[:,'column_2' ] = 'zayan'
df1

column_1	column_2	column_3	column_4	column_5	column_6
1	0.759719	zayan	0.719767	0.097453	0.356425	0.774325
2	0.175775	zayan	0.080876	0.305203	0.463609	0.147409
3	0.939736	zayan	0.773029	0.632783	0.991031	0.556814
4	0.010851	zayan	0.547391	0.155455	0.126897	0.779735
5	0.341415	zayan	0.348300	0.366254	0.970265	0.842417
6	0.264730	zayan	0.268123	0.101389	0.972870	0.155139
df1['column_2'].mean()
TypeError: Could not convert zayanzayanzayanzayanzayanzayan to numeric


Q6 ANS=
A window is a value (in terms of rows) that tells us the distance between our current row and the row which is to be used for
calculations. Windows function in Pandas can be broadly divided into three categories namely- Aggregate, Ranking, and Value.

Q7 ANS =
from datetime import datetime
  
today = datetime.now()
  
print("Current Date and Time :", today)
print("Current Month :", today.month)
output
Current month:  7
Current year:  2023

Q8 ANS=
from datetime import datetime

# dates in string format
str_d1 = input('Enter a date 1 as YYYY-MM-DD:')
str_d2 = input('Enter a date 2 as YYYY-MM-DD:')
d1 = datetime.strptime(str_d1, "%Y-%m-%d")
d2 = datetime.strptime(str_d2, "%Y-%m-%d")


delta = d2 - d1
print(delta)
print(f'Difference is {delta.days} days')
min = {(delta.days)*24}
print('difference in minutes:', min)

output
Enter a date 1 as YYYY-MM-DD: 2023-2-3
Enter a date 2 as YYYY-MM-DD: 2023-3-3
28 days, 0:00:00
Difference is 28 days
difference in minutes: {672}

Q 9 
ANS=

# %%
import pandas as pd
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1 = df['Survived']

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df2 =pd.Categorical(df1)

# %%
df2
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
type(df2)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
Q 10 
ANS=

# %%
import pandas as pd
df4= pd.read_csv("https://gist.githubusercontent.com/fishtai0/5975c7e38c8566b9b3144e45a99b65cf/raw/941a7ecbab78d6032393ba8eed6579a563f126d6/company-sales.csv")
df4
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df4.plot.bar(x='month_number',y='facecream')
# Out:
# <AxesSubplot: xlabel='month_number'>

# %%
Q 11
ANS=

# %%
import pandas as pd
df5 = pd.read_csv('student_data.csv')
df5
# Out:
#    Student ID  Test Score
# 0           1          85
# 1           2          90
# 2           3          80
# 3           4          75
# 4           5          85
# 5           6          82
# 6           7          78
# 7           8          85
# 8           9          90
# 9          10          85

# %%
df5['result_mean'] = df5['Test Score'].mean()

# %%
df5
# Out:
#    Student ID  Test Score  result_mean
# 0           1          85         83.5
# 1           2          90         83.5
# 2           3          80         83.5
# 3           4          75         83.5
# 4           5          85         83.5
# 5           6          82         83.5
# 6           7          78         83.5
# 7           8          85         83.5
# 8           9          90         83.5
# 9          10          85         83.5

# %%
df5['result_mode'] = df5['Test Score'].mode()
df5
# Out:
#    Student ID  Test Score  result_mean  result_mode
# 0           1          85         83.5         85.0
# 1           2          90         83.5          NaN
# 2           3          80         83.5          NaN
# 3           4          75         83.5          NaN
# 4           5          85         83.5          NaN
# 5           6          82         83.5          NaN
# 6           7          78         83.5          NaN
# 7           8          85         83.5          NaN
# 8           9          90         83.5          NaN
# 9          10          85         83.5          NaN

# %%
df5['result_median'] = df5['Test Score'].median()
df5
# Out:
#    Student ID  Test Score  result_mean  result_mode  result_median
# 0           1          85         83.5         85.0           85.0
# 1           2          90         83.5          NaN           85.0
# 2           3          80         83.5          NaN           85.0
# 3           4          75         83.5          NaN           85.0
# 4           5          85         83.5          NaN           85.0
# 5           6          82         83.5          NaN           85.0
# 6           7          78         83.5          NaN           85.0
# 7           8          85         83.5          NaN           85.0
# 8           9          90         83.5          NaN           85.0
# 9          10          85         83.5          NaN           85.0
