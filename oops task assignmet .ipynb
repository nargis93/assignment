# %%
"OOPS TASK ASSIGNMENT QUESTIONS"
Ans 1 
\\Program\\ 
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

car = Vehicle("innova",220, 10000)
print(car.name,car.max_speed, car.mileage)
Output:
     innova 220 10000   

Ans 2 
\\Program\\
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"
class bus(Vehicle):
    
    def seating_capacity(self, capacity=50):
        return f"The seating capacity of a {self.name} is {capacity} passengers"
    
bus("school bus", 120, 2990).seating_capacity()

Output:
    'The seating capacity of a school bus is 50 passengers'
    
Ans 3 
If a child class inherits from more than one class, i.e. this child class is derived from multiple classes,
 we call it multiple inheritance in Python.
\\program\\
class class1:
    
    def test_class1(self):
        return"this is first class"
class class2:
    
    def test_class2(self):
        return "this is seecond class"
class class3(class1,class2):
    pass
obj_class3 = class3()
obj_class3.tets_class1()
'this is first class'
obj_class3.test_class2()
'this is seecond class'

Ans4 =
Getter: A method that allows you to access
an attribute in a given class. Setter: A method that allows you to set or mutate the value of an attribute in a class.

\\program\\
class car :
    def __init__(self,year,make,model,speed):
        
        self.__year = year 
        self.__make = make 
        self.__model = model
        self.__speed = 0 
        
    def set_speed(self,speed):
        self.__speed = 0 if speed < 0 else speed
        
    def get_speed(self):
        return self.__speed 
c= car (2021,"toyota","innova", 12)
c._car__year
2021
c.set_speed(-3242)
c.get_speed()
0
c.set_speed(343)
c.get_speed()
343
Ans 5 = 
    Method overriding is a feature of object-oriented programming languages where the subclass or child class 
    can provide the program with specific characteristics or a specific implementation process of data provided 
    that are already defined in the parent class or superclass.
\\program\\
# Parent class 
class Shape:
    # properties 
    data1 = "abc"

    # function no_of_sides 
    def no_of_sides(self):
        print("My sides need to be defined. I am from shape class.")

    # function two_dimensional 
    def two_dimensional(self):
        print("I am a 2D object. I am from shape class")
class Square (Shape):
    data2 = "XYZ"

    def no_of_sides (self):
        print("I have 4 sides. I am from Square class")

    def color(self):
        print("I have teal color. I am from Square class.")

# Create an object of Square class 
sq = Square() 
# Override the no_of_sides of parent class 
sq.no_of_sides() 
# Will inherit this method from the parent class
sq.two_dimensional() 
# It's own method color 
sq.color()
Output:
I have 4 sides. I am from Square class
I am a 2D object. I am from shape class
I have teal color. I am from Square class.
